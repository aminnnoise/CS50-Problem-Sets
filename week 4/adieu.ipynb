# %%
import inflect

engine = inflect.engine()


adieu = 'Adieu, adieu, to'
names_input= []

while True:
    try:
        user = input("Name: ")
        names_input.append(user)
    except EOFError:
        print('')
        break


answer = engine.join(names_input)
print(adieu,answer)
