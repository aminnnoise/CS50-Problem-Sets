# %%
def main():
    text = input('say something:')
    for i in range(len(text)):
        if text[i] == ':':
            emoji = text[i]+text[i+1]
            convert(emoji)
            continue
        if text[i] in [')','(']:
            continue
        else:
            print(text[i] , end="")

def convert(emoji):
    if emoji == ':)' :
        print('🙂' , end = "")
    elif emoji == ':(' :
        print('🙁' , end = "")

main()
# Out:
# say something: salam :( l :)
# salam 🙁 l 🙂

# %%
def main():
    text = input('say something:')
    print(convert(text))

def convert(text):
    return text.replace(':)' , '🙂').replace(':(',"🙁")

main()
# Out:
# say something: s :) k :(
# s 🙂 k 🙁

# %%
def main():
    text = input()
    text = convert(text)
    print(text)

def convert(text):
    text = text.replace(':)','🙂')
    text = text.replace(':(','🙁')
    return text

main()
# Out:
#  salam :) khobam :(
# salam 🙂 khobam 🙁
