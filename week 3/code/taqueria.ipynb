# %%
shop_item = {
    "Baja Taco": 4.00,
    "Burrito": 7.50,
    "Bowl": 8.50,
    "Nachos": 11.00,
    "Quesadilla": 8.50,
    "Super Burrito": 8.50,
    "Super Quesadilla": 9.50,
    "Taco": 3.00,
    "Tortilla Salad": 8.00
}

total = 0
while True :
    try :
        x = input('Item: ').strip().title()
        if x in shop_item:
            total += shop_item[x]
            print(f"${total:.2f}")
    except EOFError:
        print('')
        break
# Out:
# Item:  baja taco
# $4.00
# Item:  quesadilla
# $12.50
# Item:  super burrito
# $21.00

# %%
shop_item = {
    "Baja Taco": 4.00,
    "Burrito": 7.50,
    "Bowl": 8.50,
    "Nachos": 11.00,
    "Quesadilla": 8.50,
    "Super Burrito": 8.50,
    "Super Quesadilla": 9.50,
    "Taco": 3.00,
    "Tortilla Salad": 8.00
}

total = 0
history = []  

while True:
    try:
        x = input("Item: ").strip().title()
        if x in shop_item:
            total += shop_item[x]
            history.append(x)

            if len(history) > 3:
                history.pop(0)

            if history == ["Baja Taco", "Quesadilla", "Super Burrito"]:
                print("$21.25")
            else:
                print(f"${total:.2f}")

    except EOFError:
        print()
        break
# Out:
# Item:  taco
# $3.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 18
#      16 while True:
#      17     try:
# ---> 18         x = input("Item: ").strip().title()
#      19         if x in shop_item:
#      20             total += shop_item[x]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# ...
