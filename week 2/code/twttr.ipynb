# %%
x = input('say something: ').strip()
vowel = ["a","e","i","o","u","A","E","I","O","U"]

for i in x:
    if i in vowel :
        continue
    print(i , end="")
# Out:
# say something:  CS50
# CS50
