# %%
 def main():
     plate = input("Plate: ").strip()
     if is_valid(plate):
         print("Valid")
     else:
         print("Invalid")

def is_valid(plate):

    for i in plate :
        if i == ".":
            return False
        
        
    if plate[0].isnumeric() and palte[1].isnumeric():
        return False
    
    if len(plate) > 6 or len(plate) < 2:
        return False

    for i in plate :
        if i.isnumeric():
            if i == '0':
                return False
            
            

    for i in plate:
        if i.isnumeric():
            if plate[-1].isalpha():
                return False
            else :
                return True



main()
# Out:
# Plate:  CS50
# Invalid

# %%
plate = 'aaaa222'
print(plate[-1].isalpha())
# Out:
# False

# %%
def main():
    plate = input("Plate: ").strip()
    if is_valid(plate):
        print("Valid")
    else:
        print("Invalid")


def end_str(a):
    if a == " ":
        return True
    array = a.split()
    for each in array:
        if (each.isnumeric()):
            continue
        return False
    return True


def is_valid(plt):
    if (plt[0].isnumeric() and plt[1].isnumeric()):
        return False
    if (len(plt) > 6 or len(plt) < 2):
        return False
    tempo = ''
    
    for one in range(len(plt)):
        
        if (plt[one].isnumeric()):
            if plt[one] == '0':
                return False
            tempo = plt[one:]
            break
    if tempo != " ":
        resault = end_str(tempo)
        if resault != True:
            return False
    return True


main()
# Out:
# Plate:  cs50
# Valid
