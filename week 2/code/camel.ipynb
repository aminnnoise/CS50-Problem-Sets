# %%
x = input("camelCase: ")

for i in x :
    if i.isupper():
        print("_" + i.lower() , end="")
        continue
    print(i , end="")
# Out:
# camelCase:  preferresFirstName
# preferres_first_name
